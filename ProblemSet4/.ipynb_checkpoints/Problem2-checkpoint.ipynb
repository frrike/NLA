# %% [markdown]
# # Problem 2

# %%
import numpy as np
from scipy.sparse.linalg import LinearOperator

# %%
def T_filter(n,alpha):
    T = [[alpha / np.pi * np.exp(-alpha*(i**2 + j**2)) 
      for j in range(n) + range(-n+1, 0)] 
     for i in range(n) + range(-n+1, 0)]
    return np.fft.fft2(T)

# %%
def new_mv(n,alpha):
    def mv(v):
        V = np.reshape(v,(n,n))
        if n > 1:
            zeros_right = [[0]*n]*(n-1)
            zeros_bottom = [[0]*(n-1)]*(2*n-1)
            V = np.concatenate((V,zeros_right))
            V = np.concatenate((V,zeros_bottom),axis = 1)
        Tv = np.fft.ifft2(np.multiply(T_filter(n,alpha),np.fft.fft2(V)))
        Tv = Tv[:n,:n].reshape(n*n)
        return Tv
    return mv

# %%
def construct(n,alpha):
    mv = new_mv(n,alpha)
    T = LinearOperator((n*n,n*n),matvec = mv)
    return T

# %%
from scipy import misc
lena = misc.lena()
n = lena.shape[0]
lena_long = lena.reshape(n*n,1)
alpha = 1./100
T = construct(n,alpha)
convolved_lena = T.matvec(lena_long)
squared_convolved_lena = convolved_lena.reshape(n,n)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(8,8))
#convolved_lena = convolved_lena.astype(np.int64)
plt.imshow(squared_convolved_lena.astype(np.int64),cmap = 'gray')
# Out:
# C:\Users\frike\AppData\Local\Continuum\Anaconda\lib\site-packages\ipykernel\__main__.py:5: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
import scipy.sparse.linalg as linalg
sol = linalg.gmres(T,convolved_lena,maxiter = 4)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-3548fe3b33ed> in <module>()
#       1 import scipy.sparse.linalg as linalg
# ----> 2 sol = linalg.gmres(T,convolved_lena,maxiter = 4)
#
# C:\Users\frike\AppData\Local\Continuum\Anaconda\lib\site-packages\scipy\sparse\linalg\isolve\iterative.pyc in gmres(A, b, x0, tol, restart, maxiter, xtype, M, callback, restrt)
#
# C:\Users\frike\AppData\Local\Continuum\Anaconda\lib\site-packages\scipy\sparse\linalg\isolve\iterative.pyc in non_reentrant(func, *a, **kw)
#      83     try:
#      84         d['__entered'] = True
# ---> 85         return func(*a, **kw)
#      86     finally:
#      87         d['__entered'] = False
#
# C:\Users\frike\AppData\Local\Continuum\Anaconda\lib\site-packages\scipy\sparse\linalg\isolve\iterative.pyc in gmres(A, b, x0, tol, restart, maxiter, xtype, M, callback, restrt)
#     476         elif (ijob == 3):
#     477             work[slice2] *= sclr2
# --> 478             work[slice2] += sclr1*matvec(work[slice1])
#     479             if resid_ready and callback is not None:
#     480                 callback(resid)
#
# C:\Users\frike\AppData\Local\Continuum\Anaconda\lib\site-packages\scipy\sparse\linalg\interface.pyc in matvec(self, x)
#     218             raise ValueError('dimension mismatch')
#     219
# --> 220         y = self._matvec(x)
#     221
#     222         if isinstance(x, np.matrix):
#
# C:\Users\frike\AppData\Local\Continuum\Anaconda\lib\site-packages\scipy\sparse\linalg\interface.pyc in _matvec(self, x)
#     458
#     459     def _matvec(self, x):
# --> 460         return self.__matvec_impl(x)
#     461
#     462     def _rmatvec(self, x):
#
# <ipython-input-3-c4bf11204f93> in mv(v)
#       7             V = np.concatenate((V,zeros_right))
#       8             V = np.concatenate((V,zeros_bottom),axis = 1)
# ----> 9         Tv = np.fft.ifft2(np.multiply(T_filter(n,alpha),np.fft.fft2(V)))
#      10         Tv = Tv[:n,:n].reshape(n*n)
#      11         return Tv
#
# <ipython-input-2-6bae2d565a07> in T_filter(n, alpha)
#       2     T = [[alpha / np.pi * np.exp(-alpha*(i**2 + j**2))
#       3       for j in range(n) + range(-n+1, 0)]
# ----> 4      for i in range(n) + range(-n+1, 0)]
#       5     return np.fft.fft2(T)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(8,8))
solution = np.array(sol[0])
solution = solution.reshape(n,n)
plt.imshow(solution.astype(np.int64),cmap = 'gray')
# Out:
# C:\Users\frike\AppData\Local\Continuum\Anaconda\lib\site-packages\ipykernel\__main__.py:4: ComplexWarning: Casting complex values to real discards the imaginary part

# %%
alpha = 1./50.
T = construct(n,alpha)
convolved_lena = T.matvec(lena_long).reshape(n,n)

# %%
alphas = [1./100,1./50,1./20,1./10]
Ts = np.array([construct(n,alpha) for alpha in alphas])
# Out:
# (4L,)

# %%
RHSs = [Ts[i].matvec(lena_long) for i in xrange(len(Ts))]

# %%
res = [[]*len(Ts)]
for i in xrange(len(Ts)):
    sol = linalg.minres(Ts[i],lena_long,callback = res[i].append)
    plt.semilogy(res[i],label = 'alpha = {}'.format(alphas[i]))
